# %%
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import plotly.express as px
import plotly.io as pio

# %%
pio.templates.default = 'plotly_white'
BASE_DIR = Path.cwd().parent

# %%
def create_df(file_names, cols, drop_cols, merge_col='id'):
  dfs = [pd.read_csv(BASE_DIR / 'row_data' / file) for file in file_names]
  df = dfs[0].merge(dfs[1][cols], on=merge_col, how='inner').drop(drop_cols, axis=1)
  return df

# %%
def missing_values(df):
    nan = pd.DataFrame({
    'Missing Values': 
        df.isnull().sum().sort_values(ascending=False),
    'Missing Values, %': 
        (df.isnull().sum()
            .sort_values(ascending=False)/len(df) * 100)
            .astype(int)
        })
    return nan[nan['Missing Values'] > 0]

# %%
file_names = ['listings_short.csv', 'listings.csv']
cols = ['id', 'description', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value']
drop_cols = ['license', 'neighbourhood_group', 'minimum_nights', 
             'calculated_host_listings_count', 'availability_365']
df_listing = create_df(file_names, cols, drop_cols)
df_listing.head()
# Out:
#        id                                         name  host_id host_name  \
# 0   32984                         City Hall, Stockholm    53396     Chris
# 1   75590            Amazing nature location by a lake   397766     Peter
# 2  164448  Double room in central Stockholm with Wi-Fi   784312        Li
# 3  170651           Petit Charm Rooftop next to heaven   814021     Marie
# 4  220851                      One room in appartement   412283   Fredric
#
#   neighbourhood  latitude  longitude        room_type  price  \
# 0  Kungsholmens  59.32779   18.04998  Entire home/apt   1350
# 1    Skarpnäcks  59.30117   18.12833  Entire home/apt    949
# 2    Södermalms  59.31389   18.06087     Private room    829
# 3    Södermalms  59.31702   18.02946  Entire home/apt    828
# 4  Kungsholmens  59.33351   18.03693     Private room    500
#
#    number_of_reviews  ... reviews_per_month  number_of_reviews_ltm  \
# 0                 24  ...              0.16                      0
# 1                 10  ...              0.09                      0
# 2                358  ...              2.52                     34
# 3                 42  ...              0.30                      3
# 4                 59  ...              0.42                      8
#
#                                          description review_scores_rating  \
# 0  <b>The space</b><br />Beautiful very bright 43...                 4.23
# 1  Apartment on the top floor, overlooking a lake...                 4.80
# 2  I am renting out a nice double room on the top...                 4.85
# 3  My place is perfect for 1 person or mabey 2 if...                 4.68
# 4  Welcome!<br /><br /><b>The space</b><br />Welc...                 4.70
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.43                       3.81                   4.29
# 1                    5.00                       4.89                   4.89
# 2                    4.87                       4.81                   4.96
# 3                    4.84                       4.55                   4.89
# 4                    4.71                       4.66                   4.91
#
#    review_scores_communication  review_scores_location  review_scores_value
# 0                         4.52                    4.81                 4.20
# 1                         5.00                    4.78                 4.78
# 2                         4.97                    4.83                 4.77
# 3                         4.92                    4.84                 4.74
# 4                         4.88                    4.83                 4.71
#
# [5 rows x 21 columns]

# %%
df_listing.describe()
# Out:
#                  id       host_id     latitude    longitude          price  \
# count  3.500000e+03  3.500000e+03  3500.000000  3500.000000    3500.000000
# mean   2.477073e+17  1.351403e+08    59.318811    18.031954    1739.584286
# std    3.442714e+17  1.489796e+08     0.030000     0.063833   11324.378729
# min    3.298400e+04  4.457000e+03    59.231950    17.773110       0.000000
# 25%    2.303341e+07  2.107260e+07    59.300792    18.004033     714.000000
# 50%    4.402951e+07  6.491766e+07    59.317900    18.049540    1100.000000
# 75%    6.482125e+17  2.208604e+08    59.337870    18.076097    1714.000000
# max    8.580712e+17  5.075826e+08    59.417742    18.166070  480500.000000
#
#        number_of_reviews  reviews_per_month  number_of_reviews_ltm  \
# count        3500.000000        2798.000000            3500.000000
# mean           26.758857           1.054982               8.879143
# std            57.409084           1.468412              19.706462
# min             0.000000           0.010000               0.000000
# 25%             1.000000           0.190000               0.000000
# 50%             6.000000           0.450000               2.000000
# 75%            24.000000           1.160000               8.000000
# max           976.000000          18.940000             571.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count           2798.000000             2780.000000
# mean               4.755425                4.804396
# std                0.537539                0.370060
# min                0.000000                1.000000
# 25%                4.720000                4.760000
# 50%                4.890000                4.910000
# 75%                5.000000                5.000000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                2780.000000            2780.000000
# mean                    4.736216               4.852939
# std                     0.424896               0.353636
# min                     1.000000               1.000000
# 25%                     4.670000               4.830000
# 50%                     4.860000               4.960000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  2780.000000             2780.000000
# mean                      4.857327                4.800428
# std                       0.344294                0.321867
# min                       1.000000                1.000000
# 25%                       4.850000                4.730000
# 50%                       4.980000                4.895000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value
# count          2780.000000
# mean              4.714601
# std               0.385781
# min               1.000000
# 25%               4.620000
# 50%               4.800000
# 75%               5.000000
# max               5.000000

# %%
missing_values(df_listing)
# Out:
#                              Missing Values  Missing Values, %
# review_scores_value                     720                 20
# review_scores_location                  720                 20
# review_scores_communication             720                 20
# review_scores_checkin                   720                 20
# review_scores_cleanliness               720                 20
# review_scores_accuracy                  720                 20
# reviews_per_month                       702                 20
# review_scores_rating                    702                 20
# last_review                             702                 20
# description                             102                  2
# name                                      1                  0

# %%
df_listing[['name', 'description']] = df_listing[['name', 'description']].fillna('')
df_listing = df_listing.fillna(0)
df_listing['host_description'] = df_listing['name'] + ' ' + df_listing['description']
df_listing.drop(['name', 'description'], axis=1, inplace=True)

# %%
px.histogram(df_listing, x='price')

# %%
df_listing.query('price > 25000 or price == 0')
# Out:
#                       id    host_id                    host_name  \
# 755             19529551  137155339               Hillerodsgrand
# 1694            43012846  310620582              Brommavik Hotel
# 1796            45571018  368998845                      Forenom
# 1797            45571095  368999421                      Forenom
# 1803            45680148  370101820                      Forenom
# 1804            45730331  343919205  Forenom APH Stockholm Kista
# 2202            53198829  430664934                      Camilla
# 3110  776549730665441181   46194379                        Jakob
# 3453  849709777456195565  505907207                     FaVillas
# 3454  849709953466213539  505907207                     FaVillas
#
#            neighbourhood   latitude  longitude        room_type   price  \
# 755       Rinkeby-Tensta  59.395560  17.949290  Entire home/apt  480500
# 1694              Bromma  59.359510  17.960110       Hotel room       0
# 1796              Bromma  59.334350  17.978660       Hotel room       0
# 1797              Bromma  59.345400  17.970010       Hotel room       0
# 1803           Norrmalms  59.337990  18.066190       Hotel room       0
# 1804      Rinkeby-Tensta  59.408130  17.951830       Hotel room       0
# 2202  Hässelby-Vällingby  59.373330  17.837490  Entire home/apt  450590
# 3110        Kungsholmens  59.323800  18.004500  Entire home/apt   99999
# 3453          Södermalms  59.323470  18.075240  Entire home/apt   25427
# 3454          Södermalms  59.322931  18.073034  Entire home/apt   25427
#
#       number_of_reviews last_review  reviews_per_month  number_of_reviews_ltm  \
# 755                   8  2019-08-01               0.12                      0
# 1694                  0           0               0.00                      0
# 1796                  3  2022-08-09               0.25                      3
# 1797                  4  2023-02-27               0.44                      4
# 1803                  8  2023-02-24               0.28                      4
# 1804                  5  2022-09-24               0.16                      2
# 2202                 11  2022-12-11               0.73                      5
# 3110                  0           0               0.00                      0
# 3453                  0           0               0.00                      0
# 3454                  0           0               0.00                      0
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 755                   5.00                    5.00                       5.00
# 1694                  0.00                    0.00                       0.00
# 1796                  3.67                    4.00                       4.00
# 1797                  4.75                    4.75                       4.75
# 1803                  4.13                    4.25                       4.50
# 1804                  3.40                    4.40                       4.80
# 2202                  5.00                    5.00                       5.00
# 3110                  0.00                    0.00                       0.00
# 3453                  0.00                    0.00                       0.00
# 3454                  0.00                    0.00                       0.00
#
#       review_scores_checkin  review_scores_communication  \
# 755                    4.71                         4.71
# 1694                   0.00                         0.00
# 1796                   2.67                         2.33
# 1797                   4.00                         4.25
# 1803                   4.13                         4.25
# 1804                   3.40                         3.20
# 2202                   5.00                         5.00
# 3110                   0.00                         0.00
# 3453                   0.00                         0.00
# 3454                   0.00                         0.00
#
#       review_scores_location  review_scores_value  \
# 755                     4.71                 4.86
# 1694                    0.00                 0.00
# 1796                    4.33                 4.00
# 1797                    4.75                 4.50
# 1803                    4.50                 3.88
# 1804                    4.20                 4.00
# 2202                    4.64                 5.00
# 3110                    0.00                 0.00
# 3453                    0.00                 0.00
# 3454                    0.00                 0.00
#
#                                        host_description
# 755   Sunny apartment 27 mins to Centralen The entir...
# 1694                                   Brommavik Hotel
# 1796                Forenom Aparthotel Stockholm Alvik
# 1797               Forenom Aparthotel Stockholm Bromma
# 1803  Forenom Serviced Apartments Stockholm Johannes...
# 1804                Forenom Aparthotel Stockholm Kista
# 2202  2:a i Hässelby Fin liten lägenhet i lugnt områ...
# 3110  Helhet Take it easy at this unique and tranqui...
# 3453  stockss place with 1 bedroom stock''s place wi...
# 3454  stockss place with 1 bedroom stock''s place wi...

# %%
df_calendar = pd.read_csv(BASE_DIR / 'row_data' / 'calendar.csv')
df_calendar['price'] = df_calendar['price'].str.replace('[\$,]', '', regex=True)
df_calendar['price'].agg(['max', 'min'])
# Out:
# max    99999.00
# min        0.00
# Name: price, dtype: object

# %%
min_price_calend = df_calendar.groupby('listing_id')['price'].min().astype(float).to_dict()
df_listing['price'] = df_listing['id'].map(min_price_calend)
df_listing.query('price > 90000')
# Out:
#                       id   host_id host_name neighbourhood  latitude  \
# 3110  776549730665441181  46194379     Jakob  Kungsholmens   59.3238
#
#       longitude        room_type    price  number_of_reviews last_review  \
# 3110    18.0045  Entire home/apt  99999.0                  0           0
#
#       reviews_per_month  number_of_reviews_ltm  review_scores_rating  \
# 3110                0.0                      0                   0.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 3110                     0.0                        0.0
#
#       review_scores_checkin  review_scores_communication  \
# 3110                    0.0                          0.0
#
#       review_scores_location  review_scores_value  \
# 3110                     0.0                  0.0
#
#                                        host_description
# 3110  Helhet Take it easy at this unique and tranqui...

# %%
df_listing.drop(3110, axis=0, inplace=True)
df_listing.fillna(0, inplace=True)

# %%
px.histogram(df_listing, x='price')

# %%
df_listing.to_csv(Path(BASE_DIR / 'staging_data' / 'listing_cleaned.csv'), index=False)

# %%
df_reviews = pd.read_csv(Path(BASE_DIR / 'row_data' / 'reviews_2023_03.csv'), parse_dates=['date'])
df_host_reviews = (df_reviews.merge(df_listing, left_on='listing_id', right_on='id', how='inner')
                      .drop(['id_x', 'id_y'], axis=1))

# %%
df_host_reviews
# Out:
#                listing_id       date  reviewer_id reviewer_name  \
# 0                   32984 2010-09-06       200247        Keenan
# 1                   32984 2010-09-12       126543          Olaf
# 2                   32984 2011-05-21       294223           Max
# 3                   32984 2011-05-28       577190           Eli
# 4                   32984 2011-06-11       521818      Jonathan
# ...                   ...        ...          ...           ...
# 93651  825983115454553546 2023-03-26    140580626        Kilian
# 93652  826818491548997858 2023-02-22     52396317          Ivar
# 93653  826818491548997858 2023-03-02    183686765           Luc
# 93654  826818491548997858 2023-03-10    112662633       Leonora
# 93655  826818491548997858 2023-03-16     77261435        Garima
#
#                                                 comments   host_id host_name  \
# 0      Great little apartment in the perfect spot in ...     53396     Chris
# 1      Nice flat in a great area. Chris sorted things...     53396     Chris
# 2      Great location, Chris was responsive by email ...     53396     Chris
# 3      Chris' place is super great and close to every...     53396     Chris
# 4      This was a \very nice apartment in a GREAT loc...     53396     Chris
# ...                                                  ...       ...       ...
# 93651  Nous avons passé un super séjour chez Göran et...   6839482     Göran
# 93652  Beautiful apartment. Central. Everything funct...  51002540   Fredrik
# 93653  Bonjour<br/>Appartement conforme au descriptif...  51002540   Fredrik
# 93654  This apartment was absolutely beautiful! It wa...  51002540   Fredrik
# 93655  Me and my husband recently booked and stayed a...  51002540   Fredrik
#
#       neighbourhood  latitude  longitude  ... reviews_per_month  \
# 0      Kungsholmens  59.32779  18.049980  ...              0.16
# 1      Kungsholmens  59.32779  18.049980  ...              0.16
# 2      Kungsholmens  59.32779  18.049980  ...              0.16
# 3      Kungsholmens  59.32779  18.049980  ...              0.16
# 4      Kungsholmens  59.32779  18.049980  ...              0.16
# ...             ...       ...        ...  ...               ...
# 93651     Norrmalms  59.34468  18.032352  ...              3.43
# 93652    Östermalms  59.33784  18.081570  ...              3.16
# 93653    Östermalms  59.33784  18.081570  ...              3.16
# 93654    Östermalms  59.33784  18.081570  ...              3.16
# 93655    Östermalms  59.33784  18.081570  ...              3.16
#
#        number_of_reviews_ltm  review_scores_rating review_scores_accuracy  \
# 0                          0                  4.23                   4.43
# 1                          0                  4.23                   4.43
# 2                          0                  4.23                   4.43
# 3                          0                  4.23                   4.43
# 4                          0                  4.23                   4.43
# ...                      ...                   ...                    ...
# 93651                      4                  5.00                   4.75
# 93652                      4                  3.75                   3.50
# 93653                      4                  3.75                   3.50
# 93654                      4                  3.75                   3.50
# 93655                      4                  3.75                   3.50
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           3.81                   4.29
# 1                           3.81                   4.29
# 2                           3.81                   4.29
# 3                           3.81                   4.29
# 4                           3.81                   4.29
# ...                          ...                    ...
# 93651                       5.00                   4.75
# 93652                       4.75                   3.75
# 93653                       4.75                   3.75
# 93654                       4.75                   3.75
# 93655                       4.75                   3.75
#
#        review_scores_communication  review_scores_location  \
# 0                             4.52                    4.81
# 1                             4.52                    4.81
# 2                             4.52                    4.81
# 3                             4.52                    4.81
# 4                             4.52                    4.81
# ...                            ...                     ...
# 93651                         4.75                    4.75
# 93652                         4.25                    4.50
# 93653                         4.25                    4.50
# 93654                         4.25                    4.50
# 93655                         4.25                    4.50
#
#        review_scores_value                                   host_description
# 0                     4.20  City Hall, Stockholm <b>The space</b><br />Bea...
# 1                     4.20  City Hall, Stockholm <b>The space</b><br />Bea...
# 2                     4.20  City Hall, Stockholm <b>The space</b><br />Bea...
# 3                     4.20  City Hall, Stockholm <b>The space</b><br />Bea...
# 4                     4.20  City Hall, Stockholm <b>The space</b><br />Bea...
# ...                    ...                                                ...
# 93651                 4.75  Room2stay Lev det enkla livet i detta fridfull...
# 93652                 3.50  Spacious & luxurious 2br Apt on Östermalms-tor...
# 93653                 3.50  Spacious & luxurious 2br Apt on Östermalms-tor...
# 93654                 3.50  Spacious & luxurious 2br Apt on Östermalms-tor...
# 93655                 3.50  Spacious & luxurious 2br Apt on Östermalms-tor...
#
# [93656 rows x 24 columns]

# %%
le = LabelEncoder()
df_host_reviews['listing_id_encod'] = le.fit_transform(df_host_reviews['listing_id'])

# %%
df_host_reviews = df_host_reviews.iloc[:, np.r_[1, 24, 0, 2:7, 23, 7:23]]
df_host_reviews.head(1)
# Out:
#         date  listing_id_encod  listing_id  reviewer_id reviewer_name  \
# 0 2010-09-06                 0       32984       200247        Keenan
#
#                                             comments  host_id host_name  \
# 0  Great little apartment in the perfect spot in ...    53396     Chris
#
#                                     host_description neighbourhood  ...  \
# 0  City Hall, Stockholm <b>The space</b><br />Bea...  Kungsholmens  ...
#
#    last_review  reviews_per_month number_of_reviews_ltm  review_scores_rating  \
# 0   2016-06-28               0.16                     0                  4.23
#
#    review_scores_accuracy review_scores_cleanliness  review_scores_checkin  \
# 0                    4.43                      3.81                   4.29
#
#    review_scores_communication  review_scores_location  review_scores_value
# 0                         4.52                    4.81                  4.2
#
# [1 rows x 25 columns]

# %%
df_host_reviews.describe()
# Out:
#        listing_id_encod    listing_id   reviewer_id       host_id  \
# count      93656.000000  9.365600e+04  9.365600e+04  9.365600e+04
# mean         970.009877  4.739066e+16  1.333695e+08  9.530174e+07
# std          665.721110  1.710297e+17  1.347262e+08  1.164429e+08
# min            0.000000  3.298400e+04  8.100000e+01  4.457000e+03
# 25%          394.000000  1.022251e+07  2.623410e+07  8.547277e+06
# 50%          862.000000  2.407486e+07  8.129398e+07  4.672032e+07
# 75%         1442.000000  4.034403e+07  2.030615e+08  1.388647e+08
# max         2797.000000  8.478345e+17  5.070302e+08  5.055461e+08
#
#            latitude    longitude         price  number_of_reviews  \
# count  93656.000000  93656.00000  93656.000000       93656.000000
# mean      59.319395     18.04902   1261.341409         149.890472
# std        0.022302      0.04854   1088.596961         158.725379
# min       59.231950     17.79731      0.000000           1.000000
# 25%       59.311760     18.03108    730.000000          41.000000
# 50%       59.322940     18.06604   1035.000000         103.000000
# 75%       59.334070     18.07506   1450.000000         200.000000
# max       59.417440     18.16607  22995.000000         976.000000
#
#        reviews_per_month  number_of_reviews_ltm  review_scores_rating  \
# count       93656.000000           93656.000000          93656.000000
# mean            2.797927              40.848947              4.754690
# std             2.711734              64.173547              0.226551
# min             0.010000               0.000000              0.000000
# 25%             0.830000               7.000000              4.640000
# 50%             2.290000              29.000000              4.810000
# 75%             3.970000              56.000000              4.900000
# max            18.940000             571.000000              5.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             93656.00000               93656.000000
# mean                  4.81090                   4.750516
# std                   0.19699                   0.253340
# min                   0.00000                   0.000000
# 25%                   4.74000                   4.660000
# 50%                   4.86000                   4.810000
# 75%                   4.93000                   4.910000
# max                   5.00000                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           93656.000000                 93656.000000
# mean                4.861461                     4.838456
# std                 0.165376                     0.201699
# min                 0.000000                     0.000000
# 25%                 4.810000                     4.780000
# 50%                 4.900000                     4.900000
# 75%                 4.950000                     4.960000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value
# count            93656.000000         93656.000000
# mean                 4.826085             4.694639
# std                  0.188714             0.208919
# min                  0.000000             0.000000
# 25%                  4.750000             4.590000
# 50%                  4.880000             4.720000
# 75%                  4.950000             4.830000
# max                  5.000000             5.000000

# %%
df_host_reviews.describe(include='object')
# Out:
#        reviewer_name comments host_name  \
# count          93656    93654     93656
# unique         19810    91384      1067
# top             Anna        .    Hedvig
# freq             576      151      4189
#
#                                          host_description neighbourhood  \
# count                                               93656         93656
# unique                                               2784            14
# top     Studio Apartment Double bed These studio apart...    Södermalms
# freq                                                  976         42496
#
#               room_type last_review
# count             93656       93656
# unique                4         752
# top     Entire home/apt  2023-03-26
# freq              70334        8027

# %%
missing_values(df_host_reviews)
# Out:
#           Missing Values  Missing Values, %
# comments               2                  0

# %%
df_host_reviews[df_host_reviews['comments'].isna() == True]
# Out:
#             date  listing_id_encod  listing_id  reviewer_id reviewer_name  \
# 47701 2019-04-23               902    25051575    244070000         David
# 62929 2019-05-30              1090    31301631    263373046        Deepak
#
#       comments    host_id    host_name  \
# 47701      NaN   26990407          Moa
# 62929      NaN  362541894  ApartDirect
#
#                                         host_description neighbourhood  ...  \
# 47701  Stor villa med sol hela dagen Stor villa på 17...    Skarpnäcks  ...
# 62929  Superior Studio Apartment with Sofa Bed Locate...        Älvsjö  ...
#
#        last_review  reviews_per_month number_of_reviews_ltm  \
# 47701   2023-01-03               0.42                     7
# 62929   2023-03-13               1.63                    24
#
#        review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 47701                  5.00                    4.88                      4.96
# 62929                  4.38                    4.52                      4.34
#
#        review_scores_checkin  review_scores_communication  \
# 47701                   4.96                         4.92
# 62929                   4.85                         4.46
#
#        review_scores_location  review_scores_value
# 47701                    4.83                 4.79
# 62929                    4.41                 4.41
#
# [2 rows x 25 columns]

# %%
df_host_reviews.dropna(subset=['comments'], inplace=True)

# %%
df_host_reviews['reviewer_id'].value_counts()
# Out:
# 348992094    31
# 24622700     25
# 110641325    16
# 10805888     11
# 280949885    11
#              ..
# 32023642      1
# 59702442      1
# 38577770      1
# 42229921      1
# 77261435      1
# Name: reviewer_id, Length: 88204, dtype: int64

# %%
df_host_reviews.query('reviewer_id == 348992094').head(10)
# Out:
#             date  listing_id_encod  listing_id  reviewer_id reviewer_name  \
# 53092 2020-11-30              1099    31347264    348992094         Roger
# 53097 2021-02-12              1099    31347264    348992094         Roger
# 53099 2021-03-20              1099    31347264    348992094         Roger
# 53132 2021-12-01              1099    31347264    348992094         Roger
# 54397 2021-04-28              1062    30553531    348992094         Roger
# 54410 2021-08-03              1062    30553531    348992094         Roger
# 54468 2022-07-08              1062    30553531    348992094         Roger
# 54786 2020-08-30              1063    30579247    348992094         Roger
# 55609 2021-02-23              1065    30685213    348992094         Roger
# 55615 2021-05-31              1065    30685213    348992094         Roger
#
#                                                 comments  host_id host_name  \
# 53092      Bra läge och mycket smidig in och utcheckning  8098890     Robin
# 53097  Bra läge och alltid bra kommunikation. Allt fu...  8098890     Robin
# 53099                     Bra läge och mycket bra boende  8098890     Robin
# 53132  Rent och fint. Allt man behöver finns. Lätt at...  8098890     Robin
# 54397  Had yet another good stayover. Easy to find an...  8098890     Robin
# 54410  Very nice place, clean and easy to check in an...  8098890     Robin
# 54468  Bra läge. Väldigt smidig in och utcheckning. A...  8098890     Robin
# 54786  Mycket trevligt och centralt boende, smidig in...  8098890     Robin
# 55609  Good location and nice, clean rooms, easy to c...  8098890     Robin
# 55615  Bra läge med smidig in och utcheckning. Mycket...  8098890     Robin
#
#                                         host_description neighbourhood  ...  \
# 53092  # 12 Studiolägenhet utan fönster(no window) Ni...  Kungsholmens  ...
# 53097  # 12 Studiolägenhet utan fönster(no window) Ni...  Kungsholmens  ...
# 53099  # 12 Studiolägenhet utan fönster(no window) Ni...  Kungsholmens  ...
# 53132  # 12 Studiolägenhet utan fönster(no window) Ni...  Kungsholmens  ...
# 54397  # 3 Studiolägenhet (3 pers) Niro Hotel Apartme...  Kungsholmens  ...
# 54410  # 3 Studiolägenhet (3 pers) Niro Hotel Apartme...  Kungsholmens  ...
# 54468  # 3 Studiolägenhet (3 pers) Niro Hotel Apartme...  Kungsholmens  ...
# 54786  # 2 Studiolägenhet (3 pers) Niro Hotel Apartme...  Kungsholmens  ...
# 55609  # 8 Studiolägenhet utan fönster (no window) Ni...  Kungsholmens  ...
# 55615  # 8 Studiolägenhet utan fönster (no window) Ni...  Kungsholmens  ...
#
#        last_review  reviews_per_month number_of_reviews_ltm  \
# 53092   2023-03-30               4.39                    58
# 53097   2023-03-30               4.39                    58
# 53099   2023-03-30               4.39                    58
# 53132   2023-03-30               4.39                    58
# 54397   2023-03-19               4.26                    72
# 54410   2023-03-19               4.26                    72
# 54468   2023-03-19               4.26                    72
# 54786   2023-03-28               5.51                    91
# 55609   2023-03-27               3.44                    53
# 55615   2023-03-27               3.44                    53
#
#        review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 53092                  4.73                    4.84                      4.78
# 53097                  4.73                    4.84                      4.78
# 53099                  4.73                    4.84                      4.78
# 53132                  4.73                    4.84                      4.78
# 54397                  4.78                    4.85                      4.86
# 54410                  4.78                    4.85                      4.86
# 54468                  4.78                    4.85                      4.86
# 54786                  4.76                    4.85                      4.78
# 55609                  4.79                    4.91                      4.84
# 55615                  4.79                    4.91                      4.84
#
#        review_scores_checkin  review_scores_communication  \
# 53092                   4.92                         4.79
# 53097                   4.92                         4.79
# 53099                   4.92                         4.79
# 53132                   4.92                         4.79
# 54397                   4.91                         4.87
# 54410                   4.91                         4.87
# 54468                   4.91                         4.87
# 54786                   4.87                         4.79
# 55609                   4.89                         4.82
# 55615                   4.89                         4.82
#
#        review_scores_location  review_scores_value
# 53092                    4.75                 4.68
# 53097                    4.75                 4.68
# 53099                    4.75                 4.68
# 53132                    4.75                 4.68
# 54397                    4.80                 4.78
# 54410                    4.80                 4.78
# 54468                    4.80                 4.78
# 54786                    4.75                 4.73
# 55609                    4.76                 4.72
# 55615                    4.76                 4.72
#
# [10 rows x 25 columns]

# %%
px.histogram(df_host_reviews, x='listing_id_encod')
