# %%
import pandas as pd
from pathlib import Path
BASE_DIR = Path.cwd().parent

# %%
df = pd.read_parquet(BASE_DIR / 'staging_data' / 'hosts_reviews_en_cleaned.parquet')

# %%
df['comments'].tolist()
# Out:
# ['great little apartment perfect spot town nice grocery store ica around corner walking distance everything gamla stan oster skansen etc public bike racks street cheap easy rent avoid stress cost hotel restaurants great way see stockholm',
#  'nice flat great area host sorted things make stay smooth easy leaving key neighbours etc thanks',
#  'great location host responsive email country time didnt meet apartment good shape plenty room two people definitely room improvement though far overall preparedness guests cleaning fridge general maintenanceupkeep space storage space guests said wed still recommend apartment anyone needing place stay stockholm thanks host',
#  'host place super great close everything quite central 10 minute walk downtown shopping 15 minutes old city museums everywhere really complete kitchen great eating stockholm expensive bed single bed really comfortable ask perfect place great neighborhood block water great jogging wont regret',
# ...
